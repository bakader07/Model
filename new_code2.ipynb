# %%
import shutil
import os
from sklearn.model_selection import KFold
import numpy as np
import tensorflow as tf
import glob
import os
from PIL import Image
from PIL import ImageFilter
import pandas as pd
import numpy as np
import shutil
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
#import scikitplot as skplt
import matplotlib.pyplot as plt
from tensorflow import keras

from keras.models import Sequential, load_model
from keras.callbacks import EarlyStopping
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import optimizers
from keras.applications.vgg19 import VGG19
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, roc_curve, auc, precision_score, recall_score
#np.random.seed(123)
import itertools

# %%
def first_model(loss, optimizer, metrics):
    model = Sequential()
    # Layer 1
    model.add(Conv2D(32, (3, 3), input_shape=(50,50, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    # Layer 2
    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    # Layer 3
    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())  

    # Add 2 final dense layers to add a classifier to the convolutional base
    model.add(Dense(64))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))

    # Compile the model
    model.compile(loss=loss, optimizer=optimizer, metrics=metrics)
    print(model.summary())
    return model

"""model1 = first_model(loss='binary_crossentropy',
                  optimizer='rmsprop',
                  metrics=['accuracy'])

model2 = first_model(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])"""
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 48, 48, 32)        896
#
#  activation_20 (Activation)  (None, 48, 48, 32)        0
#
#  max_pooling2d_12 (MaxPoolin  (None, 24, 24, 32)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 22, 22, 32)        9248
#
#  activation_21 (Activation)  (None, 22, 22, 32)        0
#
#  max_pooling2d_13 (MaxPoolin  (None, 11, 11, 32)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 9, 9, 64)          18496
#
#  activation_22 (Activation)  (None, 9, 9, 64)          0
#
#  max_pooling2d_14 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 1024)              0
#
#  dense_8 (Dense)             (None, 64)                65600
#
#  activation_23 (Activation)  (None, 64)                0
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 1)                 65
#
#  activation_24 (Activation)  (None, 1)                 0
#
# =================================================================
# Total params: 94,305
# Trainable params: 94,305
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 48, 48, 32)        896
#
#  activation_20 (Activation)  (None, 48, 48, 32)        0
#
#  max_pooling2d_12 (MaxPoolin  (None, 24, 24, 32)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 22, 22, 32)        9248
#
#  activation_21 (Activation)  (None, 22, 22, 32)        0
#
#  max_pooling2d_13 (MaxPoolin  (None, 11, 11, 32)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 9, 9, 64)          18496
#
#  activation_22 (Activation)  (None, 9, 9, 64)          0
#
#  max_pooling2d_14 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 1024)              0
#
#  dense_8 (Dense)             (None, 64)                65600
#
#  activation_23 (Activation)  (None, 64)                0
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 1)                 65
#
#  activation_24 (Activation)  (None, 1)                 0
#
# =================================================================
# Total params: 94,305
# Trainable params: 94,305
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
infected_path = "C:/Users/Dell/Downloads/cell_images/Parasitized/"
uninfected_path = "C:/Users/Dell/Downloads/cell_images/Uninfected/"
infected_files = os.listdir(infected_path)
uninfected_files = os.listdir(uninfected_path)

# Define functions for data preprocessing
def preprocess_data(file_list, label):
    data = []
    labels = []
    for file in file_list:
        try:
            image = tf.keras.preprocessing.image.load_img(file, target_size=(50, 50))
            image_array = tf.keras.preprocessing.image.img_to_array(image)
            data.append(image_array)
            labels.append(label)
        except Exception as e:
            print(f"Error processing {file}: {e}")
    return data, labels

# Preprocess infected and uninfected data
infected_data, infected_labels = preprocess_data([os.path.join(infected_path, f) for f in infected_files], 1)
uninfected_data, uninfected_labels = preprocess_data([os.path.join(uninfected_path, f) for f in uninfected_files], 0)

# Combine data and labels
data = np.array(infected_data + uninfected_data)
labels = np.array(infected_labels + uninfected_labels)
print(len(data))
# Out:
# Error processing C:/Users/Dell/Downloads/cell_images/Parasitized/Thumbs.db: cannot identify image file <_io.BytesIO object at 0x0000015D09221D50>
# Error processing C:/Users/Dell/Downloads/cell_images/Uninfected/Thumbs.db: cannot identify image file <_io.BytesIO object at 0x0000015D09221D50>
# 27558

# %%
epochs = 5 # CHANGE TO 200 ON THE SERVER
batch_sizes = [4, 8, 16, 24, 36]

kFold=KFold(n_splits=len(batch_sizes), shuffle=True)
results=[]
models=[]
i = 0
for train_index,test_index in kFold.split(data):
    X_train, X_test, y_train, y_test = data[train_index], data[test_index], labels[train_index], labels[test_index]
    print("Train Index: ", train_index)
    print("Test Index: ", test_index)
    batch_size = batch_sizes[i]
    
    # from here
    model = first_model(loss='binary_crossentropy',
                      optimizer='rmsprop',
                      metrics=['accuracy'])
    result = model.fit(
        X_train,y_train,
        epochs=epochs, # num of epochs will dictate speed of model 
        validation_data=(X_test, y_test),
        batch_size = batch_size,
        )
    results.append(result)
    models.append(model)
    # to here
    
    model = first_model(loss='binary_crossentropy',
                      optimizer='adam',
                      metrics=['accuracy'])
    result = model.fit(
        X_train,y_train,
        epochs=epochs, # num of epochs will dictate speed of model 
        validation_data=(X_test, y_test),
        batch_size = batch_size,
        )
    results.append(result)
    models.append(model)
    
    i +=1

    """X_train.append(data[train_index])
    X_test.append(data[test_index])
    y_train.append(labels[train_index])
    y_test.append(labels[test_index])"""

"""for res in results:
    print(res.history.values())"""
# Out:
# Train Index:  [    0     1     3 ... 27555 27556 27557]
# Test Index:  [    2     8     9 ... 27540 27547 27553]
# Epoch 1/5
# 5512/5512 [==============================] - 44s 8ms/step - loss: 0.4113 - accuracy: 0.8671 - val_loss: 0.2445 - val_accuracy: 0.9465
# Epoch 2/5
# 5512/5512 [==============================] - 48s 9ms/step - loss: 0.3416 - accuracy: 0.9267 - val_loss: 0.3371 - val_accuracy: 0.9169
# Epoch 3/5
# 5512/5512 [==============================] - 49s 9ms/step - loss: 0.3369 - accuracy: 0.9266 - val_loss: 0.2295 - val_accuracy: 0.9354
# Epoch 4/5
# 5512/5512 [==============================] - 49s 9ms/step - loss: 0.3589 - accuracy: 0.9233 - val_loss: 0.3851 - val_accuracy: 0.9376
# Epoch 5/5
# 5512/5512 [==============================] - 49s 9ms/step - loss: 0.3922 - accuracy: 0.9210 - val_loss: 0.5945 - val_accuracy: 0.9501
# Epoch 1/5
# 5512/5512 [==============================] - 55s 10ms/step - loss: 0.3557 - accuracy: 0.8806 - val_loss: 0.1929 - val_accuracy: 0.9309
# Epoch 2/5
# 5512/5512 [==============================] - 54s 10ms/step - loss: 0.1919 - accuracy: 0.9393 - val_loss: 0.1814 - val_accuracy: 0.9370
# Epoch 3/5
# 5512/5512 [==============================] - 53s 10ms/step - loss: 0.1724 - accuracy: 0.9483 - val_loss: 0.1739 - val_accuracy: 0.9472
# Epoch 4/5
# 5512/5512 [==============================] - 52s 9ms/step - loss: 0.1652 - accuracy: 0.9480 - val_loss: 0.1618 - val_accuracy: 0.9519
# Epoch 5/5
# 5512/5512 [==============================] - 52s 9ms/step - loss: 0.1655 - accuracy: 0.9502 - val_loss: 0.1602 - val_accuracy: 0.9537
# Train Index:  [    0     1     2 ... 27555 27556 27557]
# Test Index:  [    3    18    19 ... 27545 27548 27551]
# Epoch 1/5
# 2756/2756 [==============================] - 35s 12ms/step - loss: 0.4479 - accuracy: 0.8460 - val_loss: 0.2660 - val_accuracy: 0.9028
# Epoch 2/5
# 2756/2756 [==============================] - 34s 12ms/step - loss: 0.2907 - accuracy: 0.9233 - val_loss: 0.2333 - val_accuracy: 0.9305
# Epoch 2/5
# 919/919 [==============================] - 22s 24ms/step - loss: 0.2285 - accuracy: 0.9319 - val_loss: 0.2526 - val_accuracy: 0.9062
# Epoch 3/5
# 919/919 [==============================] - 22s 24ms/step - loss: 0.2198 - accuracy: 0.9362 - val_loss: 0.2633 - val_accuracy: 0.9421
# Epoch 4/5
# 919/919 [==============================] - 21s 23ms/step - loss: 0.2287 - accuracy: 0.9366 - val_loss: 0.2535 - val_accuracy: 0.9038
# Epoch 5/5
# 919/919 [==============================] - 21s 23ms/step - loss: 0.2127 - accuracy: 0.9361 - val_loss: 0.2383 - val_accuracy: 0.9173
# Epoch 1/5
# 919/919 [==============================] - 23s 23ms/step - loss: 0.6019 - accuracy: 0.8004 - val_loss: 0.2346 - val_accuracy: 0.9127
# Epoch 2/5
# 919/919 [==============================] - 22s 24ms/step - loss: 0.2312 - accuracy: 0.9221 - val_loss: 0.1754 - val_accuracy: 0.9421
# Epoch 3/5
# 919/919 [==============================] - 23s 25ms/step - loss: 0.1976 - accuracy: 0.9368 - val_loss: 0.1717 - val_accuracy: 0.9430
# Epoch 4/5
# 919/919 [==============================] - 21s 23ms/step - loss: 0.1811 - accuracy: 0.9415 - val_loss: 0.1592 - val_accuracy: 0.9486
# Epoch 5/5
# 919/919 [==============================] - 22s 23ms/step - loss: 0.1684 - accuracy: 0.9461 - val_loss: 0.1647 - val_accuracy: 0.9434
# Train Index:  [    0     2     3 ... 27554 27555 27556]
# Test Index:  [    1     4     5 ... 27529 27549 27557]
# Epoch 1/5
# 613/613 [==============================] - 20s 31ms/step - loss: 0.5728 - accuracy: 0.7657 - val_loss: 0.3118 - val_accuracy: 0.8978
# Epoch 2/5
# 613/613 [==============================] - 20s 32ms/step - loss: 0.2333 - accuracy: 0.9295 - val_loss: 0.2210 - val_accuracy: 0.9321
# Epoch 3/5
# 613/613 [==============================] - 20s 33ms/step - loss: 0.2152 - accuracy: 0.9355 - val_loss: 0.2121 - val_accuracy: 0.9356
# Epoch 4/5
# 613/613 [==============================] - 20s 32ms/step - loss: 0.2091 - accuracy: 0.9385 - val_loss: 0.2032 - val_accuracy: 0.9539
# Epoch 5/5
# 613/613 [==============================] - 20s 33ms/step - loss: 0.2082 - accuracy: 0.9407 - val_loss: 0.1669 - val_accuracy: 0.9519
# Epoch 1/5
# 613/613 [==============================] - 23s 33ms/step - loss: 0.7944 - accuracy: 0.5244 - val_loss: 0.6931 - val_accuracy: 0.5003
# Epoch 2/5
# 613/613 [==============================] - 20s 32ms/step - loss: 0.6932 - accuracy: 0.4968 - val_loss: 0.6931 - val_accuracy: 0.4992
# Epoch 3/5
# 613/613 [==============================] - 20s 33ms/step - loss: 0.6930 - accuracy: 0.5051 - val_loss: 0.6931 - val_accuracy: 0.5006
# Epoch 4/5
# 613/613 [==============================] - 20s 33ms/step - loss: 0.6931 - accuracy: 0.4924 - val_loss: 0.6947 - val_accuracy: 0.4994
# Epoch 5/5
# 613/613 [==============================] - 20s 32ms/step - loss: 0.6931 - accuracy: 0.4995 - val_loss: 0.6932 - val_accuracy: 0.4995
# 'for res in results:\n    print(res.history.values())'

# %%
i = 0
for res in results:
    print("===== Model", i, ": =====")
    print("Training:")
    print("Accuracy:", format(res.history['accuracy'][-1], ".2%"))
    print("Loss:", format(res.history['loss'][-1]), '\n')
    print("Validation:")
    print("Accuracy:", format(res.history['val_accuracy'][-1], ".2%"))
    print("Loss:", format(res.history['val_loss'][-1]), '\n')
    i += 1
# Out:
# ===== Model 0 : =====
# Training:
# Accuracy: 92.10%
# Loss: 0.39224347472190857
#
# Validation:
# Accuracy: 95.01%
# Loss: 0.5945479273796082
#
# ===== Model 1 : =====
# Training:
# Accuracy: 95.02%
# Loss: 0.1654559075832367
#
# Validation:
# Accuracy: 95.37%
# Loss: 0.16018608212471008
#
# ===== Model 2 : =====
# Training:
# Accuracy: 92.67%
# Loss: 0.3272690176963806
#
# Validation:
# Accuracy: 91.87%
# Loss: 0.25185754895210266
#
# ===== Model 3 : =====
# Training:
# Accuracy: 50.21%
# Loss: 0.693182110786438
#
# Validation:
# Accuracy: 50.29%
# Loss: 0.6931341886520386
#
# ===== Model 4 : =====
# Training:
# Accuracy: 49.94%
# Loss: 0.6933165192604065
#
# Validation:
# Accuracy: 50.76%
# Loss: 0.6931413412094116
#
# ===== Model 5 : =====
# Training:
# Accuracy: 95.11%
# Loss: 0.15542718768119812
#
# Validation:
# Accuracy: 94.87%
# Loss: 0.15625451505184174
#
# ===== Model 6 : =====
# Training:
# Accuracy: 93.61%
# Loss: 0.21268057823181152
#
# Validation:
# Accuracy: 91.73%
# Loss: 0.2383434772491455
#
# ===== Model 7 : =====
# Training:
# Accuracy: 94.61%
# Loss: 0.16841743886470795
#
# Validation:
# Accuracy: 94.34%
# Loss: 0.16468149423599243
#
# ===== Model 8 : =====
# Training:
# Accuracy: 94.07%
# Loss: 0.2081906795501709
#
# Validation:
# Accuracy: 95.19%
# Loss: 0.16688843071460724
#
# ===== Model 9 : =====
# Training:
# Accuracy: 49.95%
# Loss: 0.6930645704269409
#
# Validation:
# Accuracy: 49.95%
# Loss: 0.6931639909744263

# %%
# Plot training loss and accuracy
for result in results:
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(result.history['loss'], label='Training Loss')
    plt.plot(result.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(result.history['accuracy'], label='Training Accuracy')
    plt.plot(result.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
# Define size
batch_size = 16 # Batch size defines the number of samples that will be propagated through the network


# Configure augmentation for training adversity
# ImageDataGenerator rescales the pixels between zero and one
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

# Set augmentation for testing
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# Read pictures in 'data/train' directory and generate batches of image data with binary labels
train_generator = train_datagen.flow(
        X_train,  
        batch_size=batch_size,
        shuffle=False
        )  

# Same generator as above, but for validation data
validation_generator = test_datagen.flow(
        X_test,
        batch_size=batch_size,
        shuffle=False)

# %%
callback = EarlyStopping(
    monitor='val_acc', 
    restore_best_weights=True,
    patience=5
)

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG19
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from sklearn.model_selection import train_test_split

# Load pre-trained VGG19 model without the top (fully connected) layers
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(50,50, 3))

# Freeze the weights of the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Create a new model on top
model = Sequential([
    base_model,
    Flatten(),
    Dense(4096, activation='relu'),
    Dense(4096, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification - malaria or not
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()
train_x, test_x, train_y, test_y = train_test_split(data, labels, test_size=0.8, random_state=111)

history = model.fit(
        X_train,y_train,
        epochs=10, # num of epochs will dictate speed of model 
        validation_data=(X_test,y_test),
        )
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 1, 1, 512)         20024384
#
#  flatten_19 (Flatten)        (None, 512)               0
#
#  dense_39 (Dense)            (None, 4096)              2101248
#
#  dense_40 (Dense)            (None, 4096)              16781312
#
#  dense_41 (Dense)            (None, 1)                 4097
#
# =================================================================
# Total params: 38,911,041
# Trainable params: 18,886,657
# Non-trainable params: 20,024,384
# _________________________________________________________________
# Epoch 1/10
# 689/689 [==============================] - 474s 683ms/step - loss: 0.5425 - accuracy: 0.8996 - val_loss: 0.1961 - val_accuracy: 0.9243
# Epoch 2/10
# 689/689 [==============================] - 479s 696ms/step - loss: 0.2027 - accuracy: 0.9215 - val_loss: 0.2200 - val_accuracy: 0.9198
# Epoch 3/10
# 689/689 [==============================] - 478s 693ms/step - loss: 0.1915 - accuracy: 0.9244 - val_loss: 0.2126 - val_accuracy: 0.9281
# Epoch 4/10
# 689/689 [==============================] - 452s 656ms/step - loss: 0.1789 - accuracy: 0.9311 - val_loss: 0.2149 - val_accuracy: 0.9240
# Epoch 5/10
# 689/689 [==============================] - 456s 663ms/step - loss: 0.1705 - accuracy: 0.9337 - val_loss: 0.2056 - val_accuracy: 0.9310
# Epoch 6/10
# 689/689 [==============================] - 480s 697ms/step - loss: 0.1613 - accuracy: 0.9363 - val_loss: 0.2064 - val_accuracy: 0.9301
# Epoch 7/10
# 689/689 [==============================] - 479s 695ms/step - loss: 0.1520 - accuracy: 0.9421 - val_loss: 0.2143 - val_accuracy: 0.9294
# Epoch 8/10
# 689/689 [==============================] - 493s 716ms/step - loss: 0.1378 - accuracy: 0.9470 - val_loss: 0.2613 - val_accuracy: 0.9271
# Epoch 9/10
# 689/689 [==============================] - 453s 658ms/step - loss: 0.1284 - accuracy: 0.9500 - val_loss: 0.2519 - val_accuracy: 0.9222
# Epoch 10/10
# 689/689 [==============================] - 444s 645ms/step - loss: 0.1180 - accuracy: 0.9558 - val_loss: 0.2579 - val_accuracy: 0.9191

# %%
import shutil
import os
from sklearn.model_selection import KFold
import numpy as np
import tensorflow as tf
import glob
import os
from PIL import Image
from PIL import ImageFilter
import pandas as pd
import numpy as np
import shutil
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
#import scikitplot as skplt
import matplotlib.pyplot as plt
from tensorflow import keras

from keras.models import Sequential, load_model
from keras.callbacks import EarlyStopping
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import optimizers
from keras.applications.vgg19 import VGG19
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, roc_curve, auc, precision_score, recall_score
#np.random.seed(123)
import itertools

# %%
# Load pre-trained VGG19 model without the top (fully connected) layers
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(50,50, 3))

# Freeze the weights of the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Create a new model on top
"""model = Sequential([
    base_model,
    Flatten(),
    Dense(4096, activation='relu'),
    Dense(4096, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification - malaria or not
])"""
print(base_model.output_shape)

model = Sequential()
model.add(base_model)
# Layer 1
model.add(Conv2D(None, (1, 1), input_shape=(None,1, 1)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Layer 2
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Layer 3
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())  

# Add 2 final dense layers to add a classifier to the convolutional base
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
print(model.summary())
# Out:
# (None, 1, 1, 512)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg19 (Functional)              │ ?                      │    20,024,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_25 (Activation)      │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_26 (Activation)      │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_27 (Activation)      │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_28 (Activation)      │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_29 (Activation)      │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,024,384 (76.39 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 20,024,384 (76.39 MB)
# None

# %%
import shutil
import os
from sklearn.model_selection import KFold
import numpy as np
import tensorflow as tf
import glob
import os
from PIL import Image
from PIL import ImageFilter
import pandas as pd
import numpy as np
import shutil
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
#import scikitplot as skplt
import matplotlib.pyplot as plt
from tensorflow import keras

from keras.models import Sequential, load_model
from keras.callbacks import EarlyStopping
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import optimizers
from keras.applications.vgg19 import VGG19
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, roc_curve, auc, precision_score, recall_score
#np.random.seed(123)
import itertools
# Load pre-trained VGG19 model without the top (fully connected) layers
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(50,50, 3))

# Freeze the weights of the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Create a new model on top
"""model = Sequential([
    base_model,
    Flatten(),
    Dense(4096, activation='relu'),
    Dense(4096, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification - malaria or not
])"""
print(base_model.output_shape)
model = Sequential([
    base_model,
    Flatten(),
    Dense(4096, activation='relu'),
    Dense(4096, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification - malaria or not
])
"""
model = Sequential()
model.add(base_model)

# Layer 1
model.add(Conv2D(64, (3, 3),input_dim=reshape_y))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Layer 2
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Layer 3
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())  

# Add 2 final dense layers to add a classifier to the convolutional base
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))
"""
# Compile the model
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
print(model.summary())
infected_path = "/Users/fadiabaissi/Downloads/cell_images/Parasitized/"
uninfected_path = "/Users/fadiabaissi/Downloads/cell_images/Uninfected/"
infected_files = os.listdir(infected_path)
uninfected_files = os.listdir(uninfected_path)

# Define functions for data preprocessing
def preprocess_data(file_list, label):
    data = []
    labels = []
    for file in file_list:
        try:
            image = tf.keras.preprocessing.image.load_img(file, target_size=(50, 50))
            image_array = tf.keras.preprocessing.image.img_to_array(image)
            data.append(image_array)
            labels.append(label)
        except Exception as e:
            print(f"Error processing {file}: {e}")
    return data, labels

# Preprocess infected and uninfected data
infected_data, infected_labels = preprocess_data([os.path.join(infected_path, f) for f in infected_files], 1)
uninfected_data, uninfected_labels = preprocess_data([os.path.join(uninfected_path, f) for f in uninfected_files], 0)

# Combine data and labels
data = np.array(infected_data + uninfected_data)
labels = np.array(infected_labels + uninfected_labels)
print(len(data))

kFold=KFold(n_splits=5,shuffle=True)
results=[]
i=1
for train_index,test_index in kFold.split(data):
    print("Train Index: ", train_index, "\n")
    print("Test Index: ", test_index)
    
    X_train, X_test, y_train, y_test = data[train_index], data[test_index], labels[train_index], labels[test_index]
    result = model.fit(
        X_train,y_train,
        epochs=100, # num of epochs will dictate speed of model 
        validation_data=(X_test,y_test),
        )
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(result.history['loss'], label='Training Loss')
    plt.plot(result.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(result.history['accuracy'], label='Training Accuracy')
    plt.plot(result.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()
    model.save("/Users/fadiabaissi/Downloads/results"+i+".keras")
    i+=1
    #results.append(result)
# Out:
# (None, 1, 1, 512)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg19 (Functional)              │ ?                      │    20,024,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,024,384 (76.39 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 20,024,384 (76.39 MB)
# None
# Error processing /Users/fadiabaissi/Downloads/cell_images/Parasitized/Thumbs.db: cannot identify image file <_io.BytesIO object at 0x3137e18a0>
# Error processing /Users/fadiabaissi/Downloads/cell_images/Parasitized/.DS_Store: cannot identify image file <_io.BytesIO object at 0x3137e18a0>
# Error processing /Users/fadiabaissi/Downloads/cell_images/Uninfected/Thumbs.db: cannot identify image file <_io.BytesIO object at 0x3137e18a0>
# Error processing /Users/fadiabaissi/Downloads/cell_images/Uninfected/.DS_Store: cannot identify image file <_io.BytesIO object at 0x3137e18a0>
# 27558
# Train Index:  [    0     1     2 ... 27553 27556 27557]
#
# Test Index:  [   14    15    16 ... 27549 27554 27555]
# Epoch 1/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 395s 570ms/step - accuracy: 0.8695 - loss: 2.3033 - val_accuracy: 0.9142 - val_loss: 0.2196
# Epoch 2/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 552s 801ms/step - accuracy: 0.9219 - loss: 0.2032 - val_accuracy: 0.9253 - val_loss: 0.1998
# Epoch 3/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 398s 577ms/step - accuracy: 0.9282 - loss: 0.1858 - val_accuracy: 0.9256 - val_loss: 0.2121
# Epoch 4/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━
100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 2364s 3s/step - accuracy: 0.9870 - loss: 0.0366 - val_accuracy: 0.9272 - val_loss: 0.7234
# Epoch 29/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 1350s 2s/step - accuracy: 0.9899 - loss: 0.0285 - val_accuracy: 0.9194 - val_loss: 0.6943
# Epoch 30/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 2325s 3s/step - accuracy: 0.9900 - loss: 0.0328 - val_accuracy: 0.9160 - val_loss: 0.6758
# Epoch 31/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 1270s 2s/step - accuracy: 0.9891 - loss: 0.0296 - val_accuracy: 0.9216 - val_loss: 0.5361
# Epoch 32/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 377s 548ms/step - accuracy: 0.9926 - loss: 0.0223 - val_accuracy: 0.9233 - val_loss: 0.6527
# Epoch 33/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 380s 551ms/step - accuracy: 0.9922 - loss: 0.0254 - val_accuracy: 0.9272 - val_loss: 0.8198
# Epoch 34/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 381s 553ms/step - accuracy: 0.9920 - loss: 0.0229 - val_accuracy: 0.9262 - val_loss: 0.7204
# Epoch 35/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 382s 554ms/step - accuracy: 0.9938 - loss: 0.0201 - val_accuracy: 0.9240 - val_loss: 0.7204
# Epoch 36/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 382s 555ms/step - accuracy: 0.9931 - loss: 0.0203 - val_accuracy: 0.9262 - val_loss: 0.6570
# Epoch 37/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 382s 555ms/step - accuracy: 0.9926 - loss: 0.0275 - val_accuracy: 0.9249 - val_loss: 0.6673
# Epoch 38/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 390s 566ms/step - accuracy: 0.9938 - loss: 0.0214 - val_accuracy: 0.9265 - val_loss: 0.8211
# Epoch 39/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 394s 573ms/step - accuracy: 0.9923 - loss: 0.0253 - val_accuracy: 0.9234 - val_loss: 0.6844
# Epoch 40/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 3630s 5s/step - accuracy: 0.9952 - loss: 0.0139 - val_accuracy: 0.9243 - val_loss: 0.7944
# Epoch 41/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 390s 565ms/step - accuracy: 0.9935 - loss: 0.0180 - val_accuracy: 0.9276 - val_loss: 0.8506
# Epoch 42/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 404s 586ms/step - accuracy: 0.9946 - loss: 0.0223 - val_accuracy: 0.9267 - val_loss: 0.9465
# Epoch 43/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 404s 587ms/step - accuracy: 0.9929 - loss: 0.0321 - val_accuracy: 0.9243 - val_loss: 0.9027
# Epoch 44/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 410s 595ms/step - accuracy: 0.9946 - loss: 0.0189 - val_accuracy: 0.9220 - val_loss: 0.7817
# Epoch 45/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 399s 580ms/step - accuracy: 0.9946 - loss: 0.0186 - val_accuracy: 0.9229 - val_loss: 0.8362
# Epoch 46/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 401s 582ms/step - accuracy: 0.9883 - loss: 0.0497 - val_accuracy: 0.9229 - val_loss: 0.7170
# Epoch 47/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 414s 601ms/step - accuracy: 0.9937 - loss: 0.0172 - val_accuracy: 0.9254 - val_loss: 0.7551
# Epoch 48/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 411s 597ms/step - accuracy: 0.9965 - loss: 0.0095 - val_accuracy: 0.9318 - val_loss: 0.8975
# Epoch 49/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 401s 582ms/step - accuracy: 0.9922 - loss: 0.0252 - val_accuracy: 0.9263 - val_loss: 0.8348
# Epoch 50/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 411s 596ms/step - accuracy: 0.9981 - loss: 0.0072 - val_accuracy: 0.9291 - val_loss: 0.9255
# Epoch 51/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.9942 - loss: 0.0159

# %%
i = 0
for res in results:
    print("===== Iteration", i, ": =====")
    print("Accuracy:", format(res.history['accuracy'][-1], ".2%"))
    print("Loss:", format(res.history['loss'][-1], ".2%"))
    i += 1
